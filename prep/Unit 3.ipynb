# %%
import statistics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.DataFrame()
df['age'] = [28, 42, 27, 24, 35, 54, 35, 37]

age_mean = sum(df.age) / len(df.age)
print(age_mean)
print(np.mean(df.age))

print(statistics.median(df.age))
print(np.median(df.age))

print(statistics.mode(df.age))

print(df['age'].var())
print(np.var(df.age))

print(np.std(df.age, ddof=1))
# Out:
# 35.25
# 35.25
# 35.0
# 35.0
# 35
# 92.5
# 80.9375
# 9.617692030835672

# %%
import statistics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pop=pd.DataFrame()
pop['low_var']=np.random.normal(60, 10, 10000)
pop['high_var']=np.random.normal(60, 100, 10000)
pop.hist(layout=(2,1), sharex=True)
plt.show()

print(pop.max())
print(pop.min())

sample=pd.DataFrame()
sample['low_var'] = np.random.choice(pop['low_var'], 100)
# Out:
# low_var      96.424547
# high_var    412.463907
# dtype: float64
# low_var      21.195175
# high_var   -310.003698
# dtype: float64

# %%
import statistics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pop=pd.DataFrame()
pop['low_var']=np.random.normal(60, 10, 10000)
pop['high_var']=np.random.normal(60, 100, 10000)
pop.hist(layout=(2,1), sharex=True)
plt.show()

print(pop.max())
print(pop.min())

sample=pd.DataFrame()
sample['low_var'] = np.random.choice(pop['low_var'], 100)
sample
# Out:
# low_var      96.424547
# high_var    412.463907
# dtype: float64
# low_var      21.195175
# high_var   -310.003698
# dtype: float64

# %%
import statistics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pop=pd.DataFrame()
pop['low_var']=np.random.normal(60, 10, 10000)
pop['high_var']=np.random.normal(60, 100, 10000)
pop.hist(layout=(2,1), sharex=True)
plt.show()

print(pop.max())
print(pop.min())

sample=pd.DataFrame()
sample['low_var'] = np.random.choice(pop['low_var'], 1000)
sample['high_var'] = np.random.choice(pop['high_var'], 1000)
sample.hist()
plt.show()
print('The sample mean is: {}'.format(sample.mean()))
sample.std(ddof=1)
# Out:
# low_var      96.263567
# high_var    463.509500
# dtype: float64
# low_var      16.831708
# high_var   -309.490338
# dtype: float64
# The sample mean is: low_var     60.071908
# high_var    55.713883
# dtype: float64
# low_var      9.999377
# high_var    97.896770
# dtype: float64

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

data = pd.DataFrame()
data['gender'] = ['male'] * 100 + ['female'] * 100
data['height'] = np.append(np.random.normal(69, 8, 100), np.random.normal(64, 5, 100))
data['weight'] = np.append(np.random.normal(195, 25, 100), np.random.normal(166, 15, 100))

data.describe()
data.groupby('gender').describe()
data.gender.value_counts()
# Out:
# female    100
# male      100
# Name: gender, dtype: int64

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

brady_array = np.array([[14], [12], [11], [10], [8], [6], [8]])
age_data = pd.DataFrame(brady_array, index = ["Greg", "Marsha", "Peter", "Jan", "Bobby", "Cindy", "Oliver"], columns = ['age'])

#age_data

#age_data.describe()

#age_data.var()

#Cindy has a birthday
brady_array2 = np.array([[14], [12], [11], [10], [8], [7], [8]])
age_data2 = pd.DataFrame(brady_array2, index = ["Greg", "Marsha", "Peter", "Jan", "Bobby", "Cindy", "Oliver"], columns = ['age'])

print(age_data2)
print(age_data2.describe())

#Jessica replaces Oliver
brady_array3 = np.array([[14], [12], [11], [10], [8], [6], [1]])
age_data3 = pd.DataFrame(brady_array3, index = ["Greg", "Marsha", "Peter", "Jan", "Bobby", "Cindy", "Jessica"], columns = ['age'])

print(age_data3)
print(age_data3.describe())
# Out:
#         age
# Greg     14
# Marsha   12
# Peter    11
# Jan      10
# Bobby     8
# Cindy     7
# Oliver    8
#              age
# count   7.000000
# mean   10.000000
# std     2.516611
# min     7.000000
# 25%     8.000000
# 50%    10.000000
# 75%    11.500000
# max    14.000000
#          age
# Greg      14
# Marsha    12
# Peter     11
# Jan       10
# Bobby      8
# Cindy      6
# Jessica    1
