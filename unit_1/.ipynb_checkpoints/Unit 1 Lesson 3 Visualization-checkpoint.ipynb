# %% [markdown]
# ### Visual analysis of likelihood of zebra mussel introduction at boat ramps in the Columbia River Basin
# #### Prepared by Robin Fladebo

# %%
import warnings
import pandas as pd
pd.set_option('display.max_rows', 1000)
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20.0, 10.0)
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    import seaborn as sns

# %% [markdown]
# Dataset found at: https://www.sciencebase.gov/catalog/item/560db5dae4b0063c9e1bcfde. Accessed on Sept 15, 2018.
#
# Background:  Wells, Steve W.; Counihan, Timothy D.; Puls, Amy; Sytsma, Mark; and Adair, Brian, "Prioritizing Zebra and Quagga Mussel Monitoring in the Columbia River Basin" (2011). Center for Lakes and Reservoirs Publications and Presentations.Paper 10. Accessed on Sept 15 2018 at: http://pdxscholar.library.pdx.edu/centerforlakes_pub/10

# %%
zmusselstmp = pd.read_csv('../Datafiles/mussels/Boatramps_CRB.csv', encoding = 'latin-1')

# %%
zmusselstmp.shape
# Out:
# (1603, 64)

# %%
list(zmusselstmp.columns.values)
# Out:
# ['Water_Name',
#  'Water_Body',
#  'County',
#  'Countycode',
#  'ST_Provinc',
#  'Location',
#  'ID',
#  'lat',
#  'lon',
#  'CRB',
#  'Lat_ra',
#  'Long_ra',
#  'mean_ca_mg_2009',
#  'mean_pH_2009',
#  'roe_2009',
#  'roe_f_2009',
#  'ramcharan09',
#  'state_ass09',
#  'roi_1_2009',
#  'roi_2_2009',
#  'Roe_rank_2009',
#  'roi_3_2009',
#  'Roi_rank_2009',
#  'Rank_sumAll_2009',
#  'Rank_sum_2009',
#  'Trips2008',
#  'Trips2010',
#  'Mn_trips_08_10',
#  'DayUsedays08',
#  'DayUsedays10',
#  'Mn_dayuse_08_10',
#  'Size_Acres',
#  'No_boats_2012',
#  'No_Tourns_2012',
#  'No_Tourns_2006_08',
#  'No_boats_2006_08',
#  'Dayuse_100thm',
#  'No_ramps',
#  'CaMax_ISDA2011',
#  'ISDA2011_Rank',
#  'Elevation_ft',
#  'Motors',
#  'Fishing',
#  'Marinas',
#  'Cold',
#  'Warm',
#  'Reports',
#  'USERS',
#  'MT_Stream_Name',
#  'Length_Miles',
#  'Drainage',
#  'Region',
#  'Boat',
#  'Total_Pressure',
#  'TotPressure_Error',
#  'Total_Trips',
#  'Resident_Pressure',
#  'Res_Pressure_error',
#  'Res_Trips',
#  'Nonresident_Pressure',
#  'Nonres_Presssure_Error',
#  'NonRes_Trips',
#  'State_Rank',
#  'Regional_Rank']

# %%
zmussels = pd.read_csv('../Datafiles/mussels/Boatramps_CRB.csv', encoding = 'latin-1', usecols = ['Water_Name', 'Water_Body', 'Drainage', 'ST_Provinc', 'CRB', 'No_ramps', 'mean_ca_mg_2009', 'Roi_rank_2009', 'Roe_rank_2009', 'roe_2009', 'ramcharan09', 'Total_Pressure', 'roi_3_2009', 'Rank_sum_2009', 'Rank_sumAll_2009'] )

# %%
list(zmussels.columns.values)
# Out:
# ['Water_Name',
#  'Water_Body',
#  'ST_Provinc',
#  'CRB',
#  'mean_ca_mg_2009',
#  'roe_2009',
#  'ramcharan09',
#  'Roe_rank_2009',
#  'roi_3_2009',
#  'Roi_rank_2009',
#  'Rank_sumAll_2009',
#  'Rank_sum_2009',
#  'No_ramps',
#  'Drainage',
#  'Total_Pressure']

# %%
zmussels.rename(columns={
    'Water_Name':'water_name',
    'Water_Body':'water_body',
    'ST_Provinc':'state_province',
    'Rank_sumAll_2009':'rank_sumall_2009',
    'Rank_sum_2009':'rank_sum_2009',
    'Roe_rank_2009':'roe_rank_2009',
    'Roi_rank_2009':'roi_rank_2009',
    'No_ramps':'num_ramps',
    'Drainage':'drainage',
    'Total_Pressure':'total_pressure',
    'CRB':'crb'
    }, inplace=True)

# %%
zmussels.mean_ca_mg_2009 = zmussels.mean_ca_mg_2009.replace('.','NaN')

# %%
zmussels.mean_ca_mg_2009 = zmussels.mean_ca_mg_2009.astype('float')

# %%
zmussels.roi_rank_2009 = zmussels.roi_rank_2009.replace('.','NaN')

# %%
zmussels.roi_rank_2009 = zmussels.roi_rank_2009.astype('float')

# %%
zmussels.roe_rank_2009 = zmussels.roe_rank_2009.replace('.','NaN')

# %%
zmussels.roe_rank_2009 = zmussels.roe_rank_2009.astype('float')

# %%
zmussels.rank_sum_2009 = zmussels.rank_sum_2009.replace('.','NaN')

# %%
zmussels.rank_sum_2009 = zmussels.rank_sum_2009.astype('float')

# %% [markdown]
# Choosing to replace '.' with zero ramps (as opposed to not known)

# %%
zmussels["num_ramps"] = zmussels["num_ramps"].replace('.','0')

# %%
zmussels.num_ramps = zmussels.num_ramps.astype('int32')

# %%
zmussels.dtypes
# Out:
# water_name           object
# water_body           object
# state_province       object
# crb                   int64
# mean_ca_mg_2009     float64
# roe_2009             object
# ramcharan09          object
# roe_rank_2009       float64
# roi_3_2009           object
# roi_rank_2009       float64
# rank_sumall_2009     object
# rank_sum_2009       float64
# num_ramps             int32
# drainage             object
# total_pressure       object
# dtype: object

# %%
zmussels = zmussels.loc[(~zmussels['state_province'].isin(['BC', 'NV']))&(zmussels['mean_ca_mg_2009'].notnull())]

# %%
zmusselsor = zmussels.loc[(zmussels['state_province']=='OR')]

# %% [markdown]
# Choose one variable and plot that variable four different ways.

# %%
#distplot plots kernel density estimate by default. for reg histogram set to False
plt.subplot(1, 2, 1)
plt.ylim(0,110)
sns.distplot(zmusselsor.mean_ca_mg_2009, kde=False)
plt.xlabel('mean Ca (mg/L)')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of mean level of Calcium (mg/L) in Bodies of Water in Oregon')
# Out:
# Text(0.5,1,'Frequency Distribution of mean level of Calcium (mg/L) in Bodies of Water in Oregon')

# %%
#density, rug, no hist
sns.distplot(zmusselsor.mean_ca_mg_2009, hist=False, rug=True)
plt.xlabel('mean Ca (mg/L)')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of mean level of Calcium (mg/L) in Bodies of Water in Oregon')
# Out:
# Text(0.5,1,'Frequency Distribution of mean level of Calcium (mg/L) in Bodies of Water in Oregon')

# %%
sns.violinplot(x="state_province", y="mean_ca_mg_2009", data=zmussels, split = True, 
               inner="stick", palette="Set3")
plt.xticks(rotation = 90);

# %% [markdown]
# Choose two continuous variables, and plot them three different ways.

# %% [markdown]
# Choose one continuous variable (num_ramps) and one categorical variable (roi_3_2009), and plot them six different ways.

# %%
zmwaid = zmussels.loc[(zmussels['state_province'].isin(['WA','ID']))]

# %%
zmwaid = zmussels.loc[(zmussels['roi_3_2009']!='.')]

# %%
sns.stripplot(x="roi_3_2009", y="num_ramps", data=zmwaid, jitter = True)
plt.xticks(rotation=90);

# %%
zmwaid.corr()
# Out:
#                  crb  mean_ca_mg_2009  roe_rank_2009  roi_rank_2009  \
# crb              NaN              NaN            NaN            NaN
# mean_ca_mg_2009  NaN         1.000000       0.886166       0.051867
# roe_rank_2009    NaN         0.886166       1.000000       0.139078
# roi_rank_2009    NaN         0.051867       0.139078       1.000000
# rank_sum_2009    NaN         0.622391       0.755619       0.753736
# num_ramps        NaN         0.122297       0.103673       0.128181
#
#                  rank_sum_2009  num_ramps
# crb                        NaN        NaN
# mean_ca_mg_2009       0.622391   0.122297
# roe_rank_2009         0.755619   0.103673
# roi_rank_2009         0.753736   0.128181
# rank_sum_2009         1.000000   0.153585
# num_ramps             0.153585   1.000000

# %% [markdown]
# sns.jointplot(x="rank_sum_2009", y="num_ramps", data=zmwaid);

# %%
z
